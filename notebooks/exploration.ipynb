# %% [markdown]
# # Exploration notebook
#
# Optional starting point before running the automated pipeline. Use this to look at the raw dataset with your own eyes before trusting the agents to work on it.
#
# Run this notebook from the project root (or adjust the path below).

# %%
import pandas as pd

df = pd.read_csv("../data/raw/adult_income.csv")
df.head()

# %%
df.shape

# %%
df.dtypes

# %%
# Missing values per column
df.isna().sum()[df.isna().sum() > 0]

# %%
# Target class balance
df["income"].value_counts(normalize=True)

# %% [markdown]
# ## Next step
#
# Once you're comfortable with the raw data, go back to the project root and run:
#
# ```bash
# python orchestrator/pipeline.py --pass 1
# ```
#
# See the README for the full step-by-step procedure.
